# %%
import sys
from ephys import rasters, core, events
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
reload(rasters)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'ephys.rasters' from '/home/brad/code/gentnerlab/ephys-analysis/ephys/rasters.pyc'>

# %%
block_path1 = '/mnt/cube/btheilma/experiments/B1235/phy051316/Pen01_Lft_AP200_ML800__Site01_Z2200__B1235_cat_P01_S01_1/'
block_path2 = '/mnt/cube/btheilma/experiments/B1235/phy051316/Pen02_Lft_AP200_ML800__Site01_Z3000__B1235_cat_P02_S01_1/'

spikes1 = core.load_spikes(block_path1)
trials1 = events.load_trials(block_path1)
fs1 = core.load_fs(block_path1)
clusters1 = core.load_clusters(block_path1)

spikes2 = core.load_spikes(block_path2)
trials2 = events.load_trials(block_path2)
fs2 = core.load_fs(block_path2)
clusters2 = core.load_clusters(block_path2)

# %%
stims = trials['stimulus'].unique()
f, pltaxes = plt.subplots(4, 4, sharey=True, figsize=(22,22))

clusterID = 8
raster_window = [-2, 2]
rec = 0

for ind, stim in enumerate(stims):
    ax = pltaxes.flatten()[ind]
    rasters.plot_raster_cell_stim(spikes, trials, clusterID, stim, 
                                  raster_window, rec, fs, ax=ax)
    ax.set_title('Cell: {} Stim: {}'.format(str(8), stim))

# %%
# Set the font dictionaries (for plot title and axis titles)
title_font = {'fontname':'Arial', 'size':'36', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} # Bottom vertical alignment for more space
axis_font = {'fontname':'Arial', 'size':'36'}

stimn = 'C_scaled_burung'
goodclu1 = clusters1[clusters1['quality']=='Good']
goodclu2 = clusters2[clusters2['quality']=='Good']
for trial in range(20):
    f, pltaxes = plt.subplots(2, 1, figsize=(22,18))
    ax = pltaxes[0]
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontname('Arial')
        label.set_fontsize(32)
    rasters.plot_raster_stim_trial(spikes1, trials1, goodclu1, stimn, trial, [-2, 2], 0, fs1, ax=ax)
    ax.set_title('P01S01 Stim: {}'.format(stimn, trial), **title_font)
  
    ax.set_ylabel('Unit ID', **axis_font)
    ax = pltaxes[1]
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontname('Arial')
        label.set_fontsize(32)
    rasters.plot_raster_stim_trial(spikes2, trials2, goodclu2, stimn, trial, [-2, 2], 0, fs2, ax=ax)
    ax.set_title('P02S01 Stim: {}'.format(stimn, trial), **title_font)
    ax.set_xlabel('Time (seconds)', **axis_font)
    ax.set_ylabel('Unit ID', **axis_font)
    plt.savefig('/home/brad/topology_figs/for_neurodinner/B1235_stim{}_trial{}_P01S01_P02S01.png'.format(stimn, trial))

# %%
ax.set_title('test')

# %%
(spikes['time_samples'] > 36929201) & (spikes['time_samples'] <= 37135920)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 395932    False
# 395933    False
# 395934    False
# 395935    False
# 395936    False
# 395937    False
# 395938    False
# 395939    False
# 395940    False
# 395941    False
# 395942    False
# 395943    False
# 395944    False
# 395945    False
# 395946    False
# 395947    False
# 395948    False
# 395949    False
# 395950    False
# 395951    False
# 395952    False
# 395953    False
# 395954    False
# 395955    False
# ...
